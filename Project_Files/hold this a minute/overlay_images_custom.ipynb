# %%
# %matplotlib inline

# %%
# Inputs:
#  Paths : bw satellite image , skeleton, inverse skeleton
# MAPS/Map_Skeletons/Ibrahim_test_skeletons/preprocessing/trimmed/trimmed_e4_d4___MAPS_Map_originals_Ibrahim_Test_ibrahim_test_bw_png_png_skeleton_lee94_png.png

# Outputs:
#  image array that is an overlay of all 3

# %%
import numpy as np
import cv2

import sys
sys.path.append("/home/jasonraiti/Documents/GitHub/USC_REU/Project_Files/Jasons_Functions/")

from open_or_show_image import *

from trim_edges import *

from erosion_dilation import *

# %%
#inputs: path1 path2 , make image 1 negative, make image 2 negative
#note only works with making images with a white background

# path to images
path1 = r'./MAPS/Map_originals/Ibrahim_Test/e4_d4_image.png'

path2 = r'./zigzag_full.png' 

path3 = r'./_d1e0___inverse_skeletons_e1_d0_negative_skeleton_png_png_medial_axis_png.png'

#original image
image1 = open_image(path1)
show_image(image1)

#skeleton image
image2 = open_image(path2)
# show_image(image2)


image3 = open_image(path3)
# show_image(image3)
# Out:
# found image at :  ./MAPS/Map_originals/Ibrahim_Test/e4_d4_image.png
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a7f4b6c5b166> in <module>
#      11 #original image
#      12 image1 = open_image(path1)
# ---> 13 show_image(image1)
#      14
#      15 #skeleton image
#
# ~/Documents/GitHub/USC_REU/Project_Files/Jasons_Functions/open_or_show_image.py in show_image(image)
#      11
#      12 def show_image(image):
# ---> 13     plt.imshow(image, cmap='gray') #map the image to black and white, white representing the line
#      14     plt.show()
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
# ...

# %%
# #inverse skel
# option = 2 # 1 = erode first 2 = dialate first 
# num_erosions = 1
# num_dilations = 2
# image3 , name = erosion_dilation(path3,option,num_erosions,num_dilations)

# %%
black_image = np.zeros((image1.shape[0],image1.shape[1])) # get black background
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d54342944594> in <module>
# ----> 1 black_image = np.zeros((image1.shape[0],image1.shape[1])) # get black background
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
#put in the background (original bw satellite image ) 

for i in range(0,image1.shape[0]):
    for j in range(0, image1.shape[1]):
        if black_image[i][j] < image1[i][j]:
            black_image[i][j] = image1[i][j]
        # elif black_image[i][j] < image2[i][j]:
        #     black_image[i][j] = image2[i][j]
        # elif black_image[i][j] < image3[i][j]:
        #     black_image[i][j] = image3[i][j]

show_image(black_image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-bb629fd9aa30> in <module>
#       1 #put in the background (original bw satellite image )
#       2
# ----> 3 for i in range(0,image1.shape[0]):
#       4     for j in range(0, image1.shape[1]):
#       5         if black_image[i][j] < image1[i][j]:
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# # overlay skeletons 

# for i in range(0,image2.shape[0]):
#     for j in range(0, image2.shape[1]):
#         if image2[i][j] > 0:
#             black_image[i][j] = 0


# --------- next image 


for i in range(0,image3.shape[0]):
    for j in range(0, image3.shape[1]):
        if image3[i][j] > 0:
            black_image[i][j] = 0


show_image(image2)

show_image(black_image)

# %%
cv2.imwrite('overlay_boundary_image.png', black_image)
# Out:
# True
