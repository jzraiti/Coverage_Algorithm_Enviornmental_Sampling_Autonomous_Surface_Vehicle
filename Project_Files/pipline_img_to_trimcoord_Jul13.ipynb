# %%
# %matplotlib inline

# %%
# Inputs:
#  Path: Image that has been converted to black and white ---> eventually should try to automate this part 
# 

# Pipeline:
#  first dilate and erode
#  then skeletonize
#  then trim
#  create way points from skeleton 
#  

# Outputs:
#  dilate/eroded image
#  skeletons
#  trimmed 
#  waypoints 


#  (for future) pipeline
#       then inverse skeletonize 
#       zig zag  
#       create waypoints from zigzag path

# %%
import csv

import sys
sys.path.append("/home/jasonraiti/Documents/GitHub/USC_REU/Project_Files/Jasons_Functions/")

from erosion_dilation import * 

from jasons_skeletonize import * 

from trim_edges import * # new_array = trim_edges(path,weight_threshold)

from generate_waypoints import *

# %%
# erosion dilation 

# path to image
path = r'./MAPS/Map_originals/Ibrahim_Test/ibrahim_test_bw.png'
option = 1 # 1 = erode first 2 = dialate first 
num_erosions = 4
num_dilations = 4

# inputs = path to image, erode first (1) or dialate first (2) .desired number of erosions, desired number of dialations 
# outputs = eroded then dialated image
e_d_image , name = erosion_dilation(path,option,num_erosions,num_dilations)
 
# print(erosion_dilation(path,option,num_erosions,num_dilations))

print(name )
# Out:
# found image at :  ./MAPS/Map_originals/Ibrahim_Test/ibrahim_test_bw.png
# e4_d4___MAPS_Map_originals_Ibrahim_Test_ibrahim_test_bw_png.png

# %%
# skeletonize 
med_axis , skeleton , skeleton_lee , thinned , thinned_partial, name , paths_list = jasons_skeletonize(name)

# %%
#trim edges

weight_threshold = 40
for skel_name in paths_list:

    trimmed_skel = trim_edges(skel_name,weight_threshold)

    # create outfile for making coordinates from 
    with open(str(skel_name) + '.txt', 'w') as f:
        for edge in trimmed_skel:
            for coordinate in edge:
                f.write(str(coordinate[0]) + ',' + str(coordinate[1]) + '\n')
# Out:
# skeleton converted to graph
#
# found image at :  e4_d4___MAPS_Map_originals_Ibrahim_Test_ibrahim_test_bw_png_png_medial_axis.png
#
#
# from locate_nodes:
# be sure you are pathing to a skeleton for locate_nodes
# (ydim , xdim) ==  (322, 329)
# No errors detected
# this skeleton has 619.0 edge lines, 316 nodes, 23 endpoints, and 0 islands.
# the skeleton is of length 1974 pixels.
# the edgelines are of average length (in pixels) 2.641357027463651, .
# this function returns total_skeleton, nodes, edges, endpoints, and island's locations in (x,y) coordinate form
#
#
#
#
# skeleton converted to graph
#
#
#
# from trim_edges:
# trimmed edges will be shown in red
# retained edges will be shown in green
# skeleton converted to graph
#
# found image at :  e4_d4___MAPS_Map_originals_Ibrahim_Test_ibrahim_test_bw_png_png_skeleton.png
#
#
# from locate_nodes:
# be sure you are pathing to a skeleton for locate_nodes
# (ydim , xdim) ==  (322, 329)
# No errors detected
# this skeleton has 65.0 edge lines, 37 nodes, 14 endpoints, and 0 islands.
# the skeleton is of length 1280 pixels.
# the edgelines are of average length (in pixels) 18.907692307692308, .
# this function returns total_skeleton, nodes, edges, endpoints, and island's locations in (x,y) coordinate form
#
#
#
#
# skeleton converted to graph
#
#
#
# from trim_edges:
# trimmed edges will be shown in red
# retained edges will be shown in green
# skeleton converted to graph
#
# found image at :  e4_d4___MAPS_Map_originals_Ibrahim_Test_ibrahim_test_bw_png_png_skeleton_lee94.png
#
#
# from locate_nodes:
# be sure you are pathing to a skeleton for locate_nodes
# (ydim , xdim) ==  (322, 329)
# No errors detected
# this skeleton has 26.0 edge lines, 14 nodes, 10 endpoints, and 0 islands.
# the skeleton is of length 1044 pixels.
# the edgelines are of average length (in pixels) 39.23076923076923, .
# this function returns total_skeleton, nodes, edges, endpoints, and island's locations in (x,y) coordinate form
#
#
#
#
# skeleton converted to graph
#
#
#
# from trim_edges:
# trimmed edges will be shown in red
# retained edges will be shown in green
# skeleton converted to graph
#
# found image at :  e4_d4___MAPS_Map_originals_Ibrahim_Test_ibrahim_test_bw_png_png_thinned.png
#
#
# from locate_nodes:
# be sure you are pathing to a skeleton for locate_nodes
# (ydim , xdim) ==  (322, 329)
# No errors detected
# this skeleton has 39.0 edge lines, 22 nodes, 10 endpoints, and 0 islands.
# the skeleton is of length 1115 pixels.
# the edgelines are of average length (in pixels) 27.76923076923077, .
# this function returns total_skeleton, nodes, edges, endpoints, and island's locations in (x,y) coordinate form
#
#
#
#
# skeleton converted to graph
#
#
#
# from trim_edges:
# trimmed edges will be shown in red
# retained edges will be shown in green
# skeleton converted to graph
#
# found image at :  e4_d4___MAPS_Map_originals_Ibrahim_Test_ibrahim_test_bw_png_png_thinned_partial.png
#
#
# from locate_nodes:
# be sure you are pathing to a skeleton for locate_nodes
# (ydim , xdim) ==  (322, 329)
# No errors detected
# this skeleton has 152583.0 edge lines, 38540 nodes, 10 endpoints, and 0 islands.
# the skeleton is of length 39007 pixels.
# the edgelines are of average length (in pixels) 0.00299509119626695, .
# this function returns total_skeleton, nodes, edges, endpoints, and island's locations in (x,y) coordinate form
#
#
#
#
# skeleton converted to graph
#
#
#
# from trim_edges:
# trimmed edges will be shown in red
# retained edges will be shown in green

# %%
input_dir = "/home/jasonraiti/Documents/GitHub/USC_REU/Project_Files/" #path to line_pttrn, config_file_line, out_file_type
line_pttrn = "e4_d4___MAPS_Map_originals_Ibrahim_Test_ibrahim_test_bw_png_png_skeleton.png.txt" # coordinate file 
config_file_line = "Ibrahim_test_config.wf" # config file 

out_file_type = "m" #option = m (stands for mission palnner) or c (csv file)
# out_file_type = "c"

generate_waypoints(input_dir + line_pttrn, input_dir + config_file_line, out_file_type)
# Out:
# 497360248447 -81.23512306990881
# 34.02490248447205 -81.23503696048633
# 34.02490248447205 -81.23495085106383
# 34.02490248447205 -81.23486474164133
# 34.02490248447205 -81.23477863221885
# 34.02490248447205 -81.23469252279635
# 34.02490248447205 -81.23460641337385
# 34.02483136645962 -81.23452030395137
# 34.0247602484472 -81.23452030395137
# 34.02468913043478 -81.23452030395137
# 34.02461801242236 -81.23452030395137
# 34.02454689440994 -81.23443419452887
# 34.024475776397516 -81.23443419452887
# 34.024404658385095 -81.23443419452887
# 34.024333540372666 -81.23434808510639
# 34.024262422360245 -81.23434808510639
# 34.02419130434782 -81.23426197568389
# 34.0241201863354 -81.23426197568389
# 34.02404906832298 -81.23426197568389
# 34.02397795031056 -81.2341758662614
# 34.02390683229814 -81.23408975683891
# 34.02383571428571 -81.23408975683891
# 34.02376459627329 -81.23408975683891
# 34.02369347826087 -81.23400364741642
# 34.023622360248446 -81.23400364741642
# 34.02874285714285 -81.23469252279635
# 34.02867173913043 -81.23460641337385
# 34.02860062111801 -81.23452030395137
