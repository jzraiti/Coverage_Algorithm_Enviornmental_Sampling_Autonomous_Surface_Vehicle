# %%
# %matplotlib inline

# %%
# Python program to explain cv2.erode() method

# importing cv2
import cv2

# importing numpy
import numpy as np

# plotting
import matplotlib.pyplot as plt

# %%
def open_image(path):
    try: 
        image = cv2.imread(path, 0) # Reading an image in grayscale mode
        print("found image at : " , path)
    except:
        print("couldn't find image at : ", path)
    return(image)

def show_image(image):
    plt.imshow(image, cmap='gray') #map the image to black and white, white representing the line 
    plt.show()
    print("Plotted")
    return

# %%
# path
path = r'picture.png'

# Reading an image in default mode
image = open_image(path)

print('what is up')
# Out:
# found image at :  picture.png
# what is up

# %%
# Window name in which image is displayed
window_name = 'Image'

# Creating kernel
kernel = np.ones((3, 3), np.uint8)

# Using cv2.erode() method
try:
    erode_image = cv2.erode(image, kernel, cv2.BORDER_REFLECT)
    dilute_image = cv2.dilate(image, kernel, iterations=1)
    print('heck hecck ')
except:
    print('fuck')
# Out:
# heck hecck

# %%
# Displaying the image
show_image( image)
# Out:
# Plotted

# %%
show_image(erode_image)
# Out:
# Plotted

# %%
show_image(dilute_image)
# Out:
# Plotted

# %%
# Using cv2.erode() method
try:
    e_d_image = image
    e_d_image = cv2.erode(e_d_image, kernel, iterations=1 ) # erode 
    e_d_image = cv2.dilate(e_d_image, kernel, iterations=1) # dilute
    
    print('heck hecck ')
except:
    print('fuck')
# Out:
# heck hecck

# %%
show_image(e_d_image)
show_image(image)
# Out:
# Plotted
# Plotted

# %%
# Using cv2.erode() method
try:
    e_d_image = image
    e_d_image = cv2.erode(e_d_image, kernel, iterations=1 ) # erode 
    e_d_image = cv2.dilate(e_d_image, kernel, iterations=1 ) # dilute
    #e_d_image = cv2.erode(e_d_image, kernel, iterations=2 ) # erode 

    # e_d_image = cv2.dilate(e_d_image, kernel, iterations=1 ) # dilute

    # e_d_image = cv2.erode(e_d_image, kernel, iterations=1 ) # erode 
    # e_d_image = cv2.dilate(e_d_image, kernel, iterations=1 ) # dilute
    
    print('heck hecck ')
except:
    print('fuck')
# Out:
# heck hecck

# %%
show_image(e_d_image)
cv2.imwrite('e4_d4_image_e2.png', e_d_image)
# Out:
# Plotted
# True

# %%
show_image(image)
# Out:
# Plotted

# %%
# Using cv2.erode() method
try:
    e_d_image = image
    e_d_image = cv2.dilate( e_d_image, kernel, iterations=4 ) # dilute
    e_d_image = cv2.erode( e_d_image, kernel, iterations=4 ) # erode 

    #e_d_image = cv2.erode( e_d_image, kernel, iterations=2 ) # erode 

    # e_d_image = cv2.dilate(e_d_image, kernel, iterations=1 ) # dilute
    # e_d_image = cv2.erode(e_d_image, kernel, iterations=1 ) # erode 
    # e_d_image = cv2.dilate(e_d_image, kernel, iterations=1 ) # dilute
    
    print('heck hecck ')
except:
    print('fuck')
# Out:
# heck hecck

# %%
show_image(e_d_image)
cv2.imwrite('d4_e4_image_e2.png', e_d_image)
# Out:
# Plotted
# True

# %%
# Using cv2.erode() method
try:
    d_e_image = image
    d_e_image = cv2.erode( d_e_image, kernel, iterations=3 ) # erode 
    d_e_image = cv2.dilate( d_e_image, kernel, iterations=3 ) # dilute
    
    #e_d_image = cv2.erode( e_d_image, kernel, iterations=2 ) # erode
    # e_d_image = cv2.dilate(e_d_image, kernel, iterations=1 ) # dilute
    print('heck hecck ')
except:
    print('fuck')
# Out:
# heck hecck

# %%
show_image(d_e_image)
cv2.imwrite('d3_e3_image.png', d_e_image)
# Out:
# Plotted
# True
